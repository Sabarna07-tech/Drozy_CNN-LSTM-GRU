# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/eeg-driver-drowsiness-dataset/dataset (2).mat

# %%
import torch
import scipy.io as sio
import numpy as np
from sklearn.metrics import accuracy_score
import torch.optim as optim
import torch.nn as nn
import matplotlib.pyplot as plt

# %%
class CNNLSTM(torch.nn.Module):
    """
    CNN-LSTM model for EEG-based drowsiness detection.
    """
    def __init__(self):
        super(CNNLSTM, self).__init__()
        self.feature=32
        self.padding= torch.nn.ReplicationPad2d((31,32,0,0))
        self.conv = torch.nn.Conv2d(1,self.feature,(1,64))
        self.batch = Batchlayer(self.feature)
        self.avgpool = torch.nn.AvgPool2d((1,8))
        self.fc = torch.nn.Linear(32, 2)
        self.softmax=torch.nn.LogSoftmax(dim=1)
        self.softmax1=torch.nn.Softmax(dim=1)
        self.lstm=torch.nn.LSTM(32, 2)
        
    def forward(self, source): 
        source = self.padding(source)
        source = self.conv(source)
        source = self.batch(source)
        source = torch.nn.ELU()(source) 
        source=self.avgpool(source)        
        source =source.squeeze()
        source=source.permute(2, 0, 1)
        source = self.lstm(source)
        source=source[1][0].squeeze()
        source = self.softmax(source)
        return source

# %%
def normalizelayer(data):
    eps=1e-05
    a_mean=data-torch.mean(data, [0,2,3],True).expand(int(data.size(0)), int(data.size(1)), int(data.size(2)),int(data.size(3)))
    b=torch.div(a_mean,torch.sqrt(torch.mean((a_mean)**2, [0,2,3],True)+eps).expand(int(data.size(0)), int(data.size(1)), int(data.size(2)),int(data.size(3))))
    return b

# %%
class Batchlayer(torch.nn.Module):
    def __init__(self, dim):
        super(Batchlayer, self).__init__()
        self.gamma=torch.nn.Parameter(torch.Tensor(1,dim,1,1))
        self.beta=torch.nn.Parameter(torch.Tensor(1,dim,1,1))
        self.gamma.data.uniform_(-0.1, 0.1)
        self.beta.data.uniform_(-0.1, 0.1)
        
    def forward(self, input):
        data=normalizelayer(input)
        gammamatrix=self.gamma.expand(int(data.size(0)), int(data.size(1)), int(data.size(2)),int(data.size(3)))
        betamatrix = self.beta.expand(int(data.size(0)), int(data.size(1)), int(data.size(2)),int(data.size(3)))
        return data*gammamatrix+betamatrix

# %%
def load_data():
    filename = '/kaggle/input/eeg-driver-drowsiness-dataset/dataset (2).mat'  # Update this to the correct path
    data = sio.loadmat(filename)
    xdata = np.array(data['EEGsample'])
    label = np.array(data['substate'])
    subIdx = np.array(data['subindex'])
    
    label = label.astype(int)
    subIdx = subIdx.astype(int)
    
    return xdata, label, subIdx

# %%
# Step 4.1: Visualize the EEG Dataset

def visualize_eeg_data(xdata, label, subIdx, subject=1, channel=28, sample_freq=128):
    """
    Visualizes EEG signals for a specific subject and channel.
    
    Parameters:
    - xdata: EEG data array
    - label: State labels (drowsy or alert)
    - subIdx: Subject indices
    - subject: Subject ID to visualize (1 to 11)
    - channel: EEG channel to visualize (e.g., 28 for Oz)
    - sample_freq: Sampling frequency (128 Hz by default)
    """
    plt.figure(figsize=(12, 6))
    
    # Extract data for the selected subject
    subject_idx = np.where(subIdx == subject)[0]
    subject_data = xdata[subject_idx][:, channel, :]
    subject_labels = label[subject_idx]

    # Plot the first few samples for visualization
    for i in range(min(5, subject_data.shape[0])):  # Plot up to 5 samples
        plt.plot(subject_data[i], label=f'Sample {i+1} - State: {subject_labels[i]}')

    plt.title(f'Subject {subject} - Channel {channel} EEG Signals')
    plt.xlabel('Time (ms)')
    plt.ylabel('Amplitude (μV)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
xdata, label, subIdx = load_data()

# %%
visualize_eeg_data(xdata, label, subIdx, subject=1, channel=28)

# %%
import matplotlib.pyplot as plt

# Initialize lists to store training and testing metrics
epoch_losses = []  # Store average loss per epoch for each subject
epoch_accuracies = []  # Store accuracy per epoch for each subject
test_losses = []  # Store test loss per epoch
test_accuracies = []  # Store test accuracy per epoch

# Train the model and track metrics
def train_model():
    xdata, label, subIdx = load_data()

    samplenum = label.shape[0]
    selectedchan = [28]  # Only channel Oz is used
    xdata = xdata[:, selectedchan, :]
    channelnum = len(selectedchan)

    lr = 1e-2  # Learning rate
    batch_size = 50
    n_epoch =15 #number of epochs
    sf = 128  # Sampling frequency

    ydata = np.zeros(samplenum, dtype=np.longlong)
    for i in range(samplenum):
        ydata[i] = label[i]

    # Use CUDA if available
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    for i in range(1, 12):
        trainindx = np.where(subIdx != i)[0]
        xtrain = xdata[trainindx]
        x_train = xtrain.reshape(xtrain.shape[0], 1, channelnum, 3 * sf)
        y_train = ydata[trainindx]

        testindx = np.where(subIdx == i)[0]
        xtest = xdata[testindx]
        x_test = xtest.reshape(xtest.shape[0], 1, channelnum, 3 * sf)
        y_test = ydata[testindx]

        train = torch.utils.data.TensorDataset(torch.from_numpy(x_train), torch.from_numpy(y_train))
        train_loader = torch.utils.data.DataLoader(train, batch_size=batch_size, shuffle=True)

        my_net = CNNLSTM().double().to(device)  # Send model to device
        optimizer = optim.Adam(my_net.parameters(), lr=lr)
        loss_class = torch.nn.NLLLoss().to(device)  # Loss on the same device

        subject_losses = []
        subject_accuracies = []

        for epoch in range(n_epoch):
            total_loss = 0.0
            my_net.train()

            for j, data in enumerate(train_loader, 0):
                inputs, labels = data
                input_data = inputs.to(device).double()
                class_label = labels.to(device).long()

                my_net.zero_grad()
                class_output = my_net(input_data)
                err_s_label = loss_class(class_output, class_label)
                err_s_label.backward()
                optimizer.step()

                total_loss += err_s_label.item()

            avg_loss = total_loss / len(train_loader)
            subject_losses.append(avg_loss)

            print(f"Subject {i} | Epoch [{epoch+1}/{n_epoch}] | Loss: {avg_loss:.4f}")

            # Evaluate the model on the test set
            my_net.eval()
            with torch.no_grad():
                x_test_tensor = torch.from_numpy(x_test).to(device).double()
                answer = my_net(x_test_tensor)
                probs = answer.cpu().numpy()
                preds = probs.argmax(axis=-1)

                acc = accuracy_score(y_test, preds)
                subject_accuracies.append(acc)

                # Calculate test loss
                test_loss = loss_class(answer, torch.tensor(y_test).to(device).long()).item()
                test_losses.append(test_loss)
                test_accuracies.append(acc)

            print(f"Subject {i} | Epoch [{epoch+1}/{n_epoch}] | Accuracy: {acc:.4f}")

        epoch_losses.append(subject_losses)
        epoch_accuracies.append(subject_accuracies)

    # Calculate and plot average accuracy per epoch across subjects
    avg_accuracies = np.mean(np.array(epoch_accuracies), axis=0)

    plt.figure()
    plt.plot(range(1, n_epoch + 1), avg_accuracies, marker='o')
    plt.title('Average Accuracy vs Epochs')
    plt.xlabel('Epoch')
    plt.ylabel('Average Accuracy')
    plt.grid(True)
    plt.show()
    # Save the trained model
    torch.save(my_net.state_dict(), "cnn_lstm_model.pth")

# %%
train_model()
# Out:
# /tmp/ipykernel_23/2407261067.py:25: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   ydata[i] = label[i]
# Subject 1 | Epoch [1/15] | Loss: 0.6917
# Subject 1 | Epoch [1/15] | Accuracy: 0.5851
# Subject 1 | Epoch [2/15] | Loss: 0.6825
# Subject 1 | Epoch [2/15] | Accuracy: 0.6117
# Subject 1 | Epoch [3/15] | Loss: 0.6747
# Subject 1 | Epoch [3/15] | Accuracy: 0.6489
# Subject 1 | Epoch [4/15] | Loss: 0.6646
# Subject 1 | Epoch [4/15] | Accuracy: 0.7021
# Subject 1 | Epoch [5/15] | Loss: 0.6417
# Subject 1 | Epoch [5/15] | Accuracy: 0.6968
# Subject 1 | Epoch [6/15] | Loss: 0.5964
# Subject 1 | Epoch [6/15] | Accuracy: 0.7606
# Subject 1 | Epoch [7/15] | Loss: 0.5726
# Subject 1 | Epoch [7/15] | Accuracy: 0.7660
# Subject 1 | Epoch [8/15] | Loss: 0.5645
# Subject 1 | Epoch [8/15] | Accuracy: 0.7872
# Subject 1 | Epoch [9/15] | Loss: 0.5594
# Subject 1 | Epoch [9/15] | Accuracy: 0.7713
# Subject 1 | Epoch [10/15] | Loss: 0.5540
# Subject 1 | Epoch [10/15] | Accuracy: 0.7766
# Subject 1 | Epoch [11/15] | Loss: 0.5570
# Subject 1 | Epoch [11/15] | Accuracy: 0.7500
# Subject 1 | Epoch [12/15] | Loss: 0.5466
# Subject 1 | Epoch [12/15] | Accuracy: 0.7394
# Subject 1 | Epoch [13/15] | Loss: 0.5502
# Subject 1 | Epoch [13/15] | Accuracy: 0.7872
# Subject 1 | Epoch [14/15] | Loss: 0.5567
# Subject 1 | Epoch [14/15] | Accuracy: 0.7766
# Subject 1 | Epoch [15/15] | Loss: 0.5453
# Subject 1 | Epoch [15/15] | Accuracy: 0.7766
# Subject 2 | Epoch [1/15] | Loss: 0.6922
# Subject 2 | Epoch [1/15] | Accuracy: 0.5606
# Subject 2 | Epoch [2/15] | Loss: 0.6820
# Subject 2 | Epoch [2/15] | Accuracy: 0.5076
# Subject 2 | Epoch [3/15] | Loss: 0.6748
# Subject 2 | Epoch [3/15] | Accuracy: 0.5606
# Subject 2 | Epoch [4/15] | Loss: 0.6453
# Subject 2 | Epoch [4/15] | Accuracy: 0.5758
# Subject 2 | Epoch [5/15] | Loss: 0.5611
# Subject 2 | Epoch [5/15] | Accuracy: 0.4848
# Subject 2 | Epoch [6/15] | Loss: 0.5257
# Subject 2 | Epoch [6/15] | Accuracy: 0.5000
# Subject 2 | Epoch [7/15] | Loss: 0.5323
# Subject 2 | Epoch [7/15] | Accuracy: 0.5227
# Subject 2 | Epoch [8/15] | Loss: 0.5213
# Subject 2 | Epoch [8/15] | Accuracy: 0.5227
# Subject 2 | Epoch [9/15] | Loss: 0.5311
# Subject 2 | Epoch [9/15] | Accuracy: 0.5606
# Subject 2 | Epoch [10/15] | Loss: 0.5203
# Subject 2 | Epoch [10/15] | Accuracy: 0.5076
# Subject 2 | Epoch [11/15] | Loss: 0.5125
# Subject 2 | Epoch [11/15] | Accuracy: 0.5455
# Subject 2 | Epoch [12/15] | Loss: 0.5106
# Subject 2 | Epoch [12/15] | Accuracy: 0.5076
# Subject 2 | Epoch [13/15] | Loss: 0.5064
# Subject 2 | Epoch [13/15] | Accuracy: 0.5000
# Subject 2 | Epoch [14/15] | Loss: 0.5100
# Subject 2 | Epoch [14/15] | Accuracy: 0.5758
# Subject 2 | Epoch [15/15] | Loss: 0.5207
# Subject 2 | Epoch [15/15] | Accuracy: 0.5379
# Subject 3 | Epoch [1/15] | Loss: 0.6944
# Subject 3 | Epoch [1/15] | Accuracy: 0.4800
# Subject 3 | Epoch [2/15] | Loss: 0.6797
# Subject 3 | Epoch [2/15] | Accuracy: 0.5200
# Subject 3 | Epoch [3/15] | Loss: 0.6681
# Subject 3 | Epoch [3/15] | Accuracy: 0.4800
# Subject 3 | Epoch [4/15] | Loss: 0.6387
# Subject 3 | Epoch [4/15] | Accuracy: 0.5467
# Subject 3 | Epoch [5/15] | Loss: 0.7567
# Subject 3 | Epoch [5/15] | Accuracy: 0.5467
# Subject 3 | Epoch [6/15] | Loss: 0.6469
# Subject 3 | Epoch [6/15] | Accuracy: 0.5667
# Subject 3 | Epoch [7/15] | Loss: 0.6043
# Subject 3 | Epoch [7/15] | Accuracy: 0.6000
# Subject 3 | Epoch [8/15] | Loss: 0.5540
# Subject 3 | Epoch [8/15] | Accuracy: 0.6200
# Subject 3 | Epoch [9/15] | Loss: 0.5483
# Subject 3 | Epoch [9/15] | Accuracy: 0.6000
# Subject 3 | Epoch [10/15] | Loss: 0.5374
# Subject 3 | Epoch [10/15] | Accuracy: 0.5600
# Subject 3 | Epoch [11/15] | Loss: 0.5324
# Subject 3 | Epoch [11/15] | Accuracy: 0.5800
# Subject 3 | Epoch [12/15] | Loss: 0.5449
# Subject 3 | Epoch [12/15] | Accuracy: 0.6200
# Subject 3 | Epoch [13/15] | Loss: 0.5370
# Subject 3 | Epoch [13/15] | Accuracy: 0.5933
# Subject 3 | Epoch [14/15] | Loss: 0.5320
# Subject 3 | Epoch [14/15] | Accuracy: 0.5800
# Subject 3 | Epoch [15/15] | Loss: 0.5251
# Subject 3 | Epoch [15/15] | Accuracy: 0.5933
# Subject 4 | Epoch [1/15] | Loss: 0.6906
# Subject 4 | Epoch [1/15] | Accuracy: 0.5068
# Subject 4 | Epoch [2/15] | Loss: 0.6801
# Subject 4 | Epoch [2/15] | Accuracy: 0.5270
# Subject 4 | Epoch [3/15] | Loss: 0.6827
# Subject 4 | Epoch [3/15] | Accuracy: 0.5811
# Subject 4 | Epoch [4/15] | Loss: 0.6509
# Subject 4 | Epoch [4/15] | Accuracy: 0.6284
# Subject 4 | Epoch [5/15] | Loss: 0.6111
# Subject 4 | Epoch [5/15] | Accuracy: 0.6554
# Subject 4 | Epoch [6/15] | Loss: 0.5658
# Subject 4 | Epoch [6/15] | Accuracy: 0.7432
# Subject 4 | Epoch [7/15] | Loss: 0.5506
# Subject 4 | Epoch [7/15] | Accuracy: 0.6622
# Subject 4 | Epoch [8/15] | Loss: 0.5604
# Subject 4 | Epoch [8/15] | Accuracy: 0.7635
# Subject 4 | Epoch [9/15] | Loss: 0.5452
# Subject 4 | Epoch [9/15] | Accuracy: 0.7365
# Subject 4 | Epoch [10/15] | Loss: 0.5374
# Subject 4 | Epoch [10/15] | Accuracy: 0.7365
# Subject 4 | Epoch [11/15] | Loss: 0.5317
# Subject 4 | Epoch [11/15] | Accuracy: 0.7297
# Subject 4 | Epoch [12/15] | Loss: 0.5357
# Subject 4 | Epoch [12/15] | Accuracy: 0.6824
# Subject 4 | Epoch [13/15] | Loss: 0.5326
# Subject 4 | Epoch [13/15] | Accuracy: 0.7432
# Subject 4 | Epoch [14/15] | Loss: 0.5269
# Subject 4 | Epoch [14/15] | Accuracy: 0.7432
# Subject 4 | Epoch [15/15] | Loss: 0.5286
# Subject 4 | Epoch [15/15] | Accuracy: 0.7365
# Subject 5 | Epoch [1/15] | Loss: 0.6920
# Subject 5 | Epoch [1/15] | Accuracy: 0.5804
# Subject 5 | Epoch [2/15] | Loss: 0.6830
# Subject 5 | Epoch [2/15] | Accuracy: 0.5670
# Subject 5 | Epoch [3/15] | Loss: 0.6780
# Subject 5 | Epoch [3/15] | Accuracy: 0.5625
# Subject 5 | Epoch [4/15] | Loss: 0.6756
# Subject 5 | Epoch [4/15] | Accuracy: 0.5804
# Subject 5 | Epoch [5/15] | Loss: 0.6715
# Subject 5 | Epoch [5/15] | Accuracy: 0.5580
# Subject 5 | Epoch [6/15] | Loss: 0.6512
# Subject 5 | Epoch [6/15] | Accuracy: 0.6339
# Subject 5 | Epoch [7/15] | Loss: 0.6182
# Subject 5 | Epoch [7/15] | Accuracy: 0.5714
# Subject 5 | Epoch [8/15] | Loss: 0.5874
# Subject 5 | Epoch [8/15] | Accuracy: 0.7723
# Subject 5 | Epoch [9/15] | Loss: 0.5652
# Subject 5 | Epoch [9/15] | Accuracy: 0.7857
# Subject 5 | Epoch [10/15] | Loss: 0.5570
# Subject 5 | Epoch [10/15] | Accuracy: 0.7545
# Subject 5 | Epoch [11/15] | Loss: 0.5524
# Subject 5 | Epoch [11/15] | Accuracy: 0.7679
# Subject 5 | Epoch [12/15] | Loss: 0.5562
# Subject 5 | Epoch [12/15] | Accuracy: 0.7411
# Subject 5 | Epoch [13/15] | Loss: 0.5431
# Subject 5 | Epoch [13/15] | Accuracy: 0.7723
# Subject 5 | Epoch [14/15] | Loss: 0.5543
# Subject 5 | Epoch [14/15] | Accuracy: 0.7366
# Subject 5 | Epoch [15/15] | Loss: 0.5372
# Subject 5 | Epoch [15/15] | Accuracy: 0.6384
# Subject 6 | Epoch [1/15] | Loss: 0.6906
# Subject 6 | Epoch [1/15] | Accuracy: 0.5241
# Subject 6 | Epoch [2/15] | Loss: 0.6838
# Subject 6 | Epoch [2/15] | Accuracy: 0.5241
# Subject 6 | Epoch [3/15] | Loss: 0.6672
# Subject 6 | Epoch [3/15] | Accuracy: 0.5904
# Subject 6 | Epoch [4/15] | Loss: 0.6542
# Subject 6 | Epoch [4/15] | Accuracy: 0.6265
# Subject 6 | Epoch [5/15] | Loss: 0.6118
# Subject 6 | Epoch [5/15] | Accuracy: 0.7771
# Subject 6 | Epoch [6/15] | Loss: 0.5872
# Subject 6 | Epoch [6/15] | Accuracy: 0.8253
# Subject 6 | Epoch [7/15] | Loss: 0.5895
# Subject 6 | Epoch [7/15] | Accuracy: 0.6687
# Subject 6 | Epoch [8/15] | Loss: 0.5669
# Subject 6 | Epoch [8/15] | Accuracy: 0.8554
# Subject 6 | Epoch [9/15] | Loss: 0.5667
# Subject 6 | Epoch [9/15] | Accuracy: 0.8373
# Subject 6 | Epoch [10/15] | Loss: 0.5573
# Subject 6 | Epoch [10/15] | Accuracy: 0.8373
# Subject 6 | Epoch [11/15] | Loss: 0.5498
# Subject 6 | Epoch [11/15] | Accuracy: 0.8434
# Subject 6 | Epoch [12/15] | Loss: 0.5561
# Subject 6 | Epoch [12/15] | Accuracy: 0.8494
# Subject 6 | Epoch [13/15] | Loss: 0.5629
# Subject 6 | Epoch [13/15] | Accuracy: 0.8373
# Subject 6 | Epoch [14/15] | Loss: 0.5466
# Subject 6 | Epoch [14/15] | Accuracy: 0.8373
# Subject 6 | Epoch [15/15] | Loss: 0.5550
# Subject 6 | Epoch [15/15] | Accuracy: 0.8373
# Subject 7 | Epoch [1/15] | Loss: 0.6893
# Subject 7 | Epoch [1/15] | Accuracy: 0.5392
# Subject 7 | Epoch [2/15] | Loss: 0.6796
# Subject 7 | Epoch [2/15] | Accuracy: 0.5588
# Subject 7 | Epoch [3/15] | Loss: 0.6797
# Subject 7 | Epoch [3/15] | Accuracy: 0.4804
# Subject 7 | Epoch [4/15] | Loss: 0.6671
# Subject 7 | Epoch [4/15] | Accuracy: 0.5588
# Subject 7 | Epoch [5/15] | Loss: 0.6460
# Subject 7 | Epoch [5/15] | Accuracy: 0.5686
# Subject 7 | Epoch [6/15] | Loss: 0.5866
# Subject 7 | Epoch [6/15] | Accuracy: 0.6373
# Subject 7 | Epoch [7/15] | Loss: 0.5863
# Subject 7 | Epoch [7/15] | Accuracy: 0.6471
# Subject 7 | Epoch [8/15] | Loss: 0.5532
# Subject 7 | Epoch [8/15] | Accuracy: 0.6569
# Subject 7 | Epoch [9/15] | Loss: 0.5527
# Subject 7 | Epoch [9/15] | Accuracy: 0.6275
# Subject 7 | Epoch [10/15] | Loss: 0.5595
# Subject 7 | Epoch [10/15] | Accuracy: 0.6569
# Subject 7 | Epoch [11/15] | Loss: 0.5497
# Subject 7 | Epoch [11/15] | Accuracy: 0.6471
# Subject 7 | Epoch [12/15] | Loss: 0.5467
# Subject 7 | Epoch [12/15] | Accuracy: 0.6569
# Subject 7 | Epoch [13/15] | Loss: 0.5395
# Subject 7 | Epoch [13/15] | Accuracy: 0.6373
# Subject 7 | Epoch [14/15] | Loss: 0.5404
# Subject 7 | Epoch [14/15] | Accuracy: 0.6373
# Subject 7 | Epoch [15/15] | Loss: 0.5305
# Subject 7 | Epoch [15/15] | Accuracy: 0.6569
# Subject 8 | Epoch [1/15] | Loss: 0.6903
# Subject 8 | Epoch [1/15] | Accuracy: 0.4886
# Subject 8 | Epoch [2/15] | Loss: 0.6782
# Subject 8 | Epoch [2/15] | Accuracy: 0.4697
# Subject 8 | Epoch [3/15] | Loss: 0.6771
# Subject 8 | Epoch [3/15] | Accuracy: 0.5568
# Subject 8 | Epoch [4/15] | Loss: 0.6368
# Subject 8 | Epoch [4/15] | Accuracy: 0.6894
# Subject 8 | Epoch [5/15] | Loss: 0.5643
# Subject 8 | Epoch [5/15] | Accuracy: 0.6932
# Subject 8 | Epoch [6/15] | Loss: 0.5475
# Subject 8 | Epoch [6/15] | Accuracy: 0.7045
# Subject 8 | Epoch [7/15] | Loss: 0.5488
# Subject 8 | Epoch [7/15] | Accuracy: 0.7008
# Subject 8 | Epoch [8/15] | Loss: 0.5257
# Subject 8 | Epoch [8/15] | Accuracy: 0.7500
# Subject 8 | Epoch [9/15] | Loss: 0.5309
# Subject 8 | Epoch [9/15] | Accuracy: 0.7121
# Subject 8 | Epoch [10/15] | Loss: 0.5441
# Subject 8 | Epoch [10/15] | Accuracy: 0.7121
# Subject 8 | Epoch [11/15] | Loss: 0.5297
# Subject 8 | Epoch [11/15] | Accuracy: 0.7311
# Subject 8 | Epoch [12/15] | Loss: 0.5351
# Subject 8 | Epoch [12/15] | Accuracy: 0.7311
# Subject 8 | Epoch [13/15] | Loss: 0.5191
# Subject 8 | Epoch [13/15] | Accuracy: 0.7197
# Subject 8 | Epoch [14/15] | Loss: 0.5332
# Subject 8 | Epoch [14/15] | Accuracy: 0.7121
# Subject 8 | Epoch [15/15] | Loss: 0.5263
# Subject 8 | Epoch [15/15] | Accuracy: 0.7008
# Subject 9 | Epoch [1/15] | Loss: 0.6968
# Subject 9 | Epoch [1/15] | Accuracy: 0.5541
# Subject 9 | Epoch [2/15] | Loss: 0.6814
# Subject 9 | Epoch [2/15] | Accuracy: 0.5796
# Subject 9 | Epoch [3/15] | Loss: 0.6815
# Subject 9 | Epoch [3/15] | Accuracy: 0.5860
# Subject 9 | Epoch [4/15] | Loss: 0.6778
# Subject 9 | Epoch [4/15] | Accuracy: 0.6274
# Subject 9 | Epoch [5/15] | Loss: 0.6741
# Subject 9 | Epoch [5/15] | Accuracy: 0.6178
# Subject 9 | Epoch [6/15] | Loss: 0.6637
# Subject 9 | Epoch [6/15] | Accuracy: 0.7102
# Subject 9 | Epoch [7/15] | Loss: 0.6550
# Subject 9 | Epoch [7/15] | Accuracy: 0.7548
# Subject 9 | Epoch [8/15] | Loss: 0.6581
# Subject 9 | Epoch [8/15] | Accuracy: 0.7643
# Subject 9 | Epoch [9/15] | Loss: 0.6325
# Subject 9 | Epoch [9/15] | Accuracy: 0.9045
# Subject 9 | Epoch [10/15] | Loss: 0.6138
# Subject 9 | Epoch [10/15] | Accuracy: 0.8535
# Subject 9 | Epoch [11/15] | Loss: 0.5976
# Subject 9 | Epoch [11/15] | Accuracy: 0.8885
# Subject 9 | Epoch [12/15] | Loss: 0.5992
# Subject 9 | Epoch [12/15] | Accuracy: 0.8758
# Subject 9 | Epoch [13/15] | Loss: 0.5856
# Subject 9 | Epoch [13/15] | Accuracy: 0.8662
# Subject 9 | Epoch [14/15] | Loss: 0.5857
# Subject 9 | Epoch [14/15] | Accuracy: 0.8822
# Subject 9 | Epoch [15/15] | Loss: 0.5697
# Subject 9 | Epoch [15/15] | Accuracy: 0.8758
# Subject 10 | Epoch [1/15] | Loss: 0.6945
# Subject 10 | Epoch [1/15] | Accuracy: 0.6389
# Subject 10 | Epoch [2/15] | Loss: 0.6803
# Subject 10 | Epoch [2/15] | Accuracy: 0.6481
# Subject 10 | Epoch [3/15] | Loss: 0.6726
# Subject 10 | Epoch [3/15] | Accuracy: 0.6667
# Subject 10 | Epoch [4/15] | Loss: 0.6487
# Subject 10 | Epoch [4/15] | Accuracy: 0.7870
# Subject 10 | Epoch [5/15] | Loss: 0.6109
# Subject 10 | Epoch [5/15] | Accuracy: 0.7778
# Subject 10 | Epoch [6/15] | Loss: 0.5842
# Subject 10 | Epoch [6/15] | Accuracy: 0.8148
# Subject 10 | Epoch [7/15] | Loss: 0.5982
# Subject 10 | Epoch [7/15] | Accuracy: 0.8519
# Subject 10 | Epoch [8/15] | Loss: 0.5760
# Subject 10 | Epoch [8/15] | Accuracy: 0.8333
# Subject 10 | Epoch [9/15] | Loss: 0.5696
# Subject 10 | Epoch [9/15] | Accuracy: 0.8519
# Subject 10 | Epoch [10/15] | Loss: 0.5673
# Subject 10 | Epoch [10/15] | Accuracy: 0.8519
# Subject 10 | Epoch [11/15] | Loss: 0.5581
# Subject 10 | Epoch [11/15] | Accuracy: 0.8704
# Subject 10 | Epoch [12/15] | Loss: 0.5550
# Subject 10 | Epoch [12/15] | Accuracy: 0.8426
# Subject 10 | Epoch [13/15] | Loss: 0.5569
# Subject 10 | Epoch [13/15] | Accuracy: 0.8611
# Subject 10 | Epoch [14/15] | Loss: 0.5658
# Subject 10 | Epoch [14/15] | Accuracy: 0.8611
# Subject 10 | Epoch [15/15] | Loss: 0.5527
# Subject 10 | Epoch [15/15] | Accuracy: 0.8519
# Subject 11 | Epoch [1/15] | Loss: 0.6942
# Subject 11 | Epoch [1/15] | Accuracy: 0.5177
# Subject 11 | Epoch [2/15] | Loss: 0.6868
# Subject 11 | Epoch [2/15] | Accuracy: 0.6106
# Subject 11 | Epoch [3/15] | Loss: 0.6820
# Subject 11 | Epoch [3/15] | Accuracy: 0.6504
# Subject 11 | Epoch [4/15] | Loss: 0.6691
# Subject 11 | Epoch [4/15] | Accuracy: 0.7035
# Subject 11 | Epoch [5/15] | Loss: 0.6225
# Subject 11 | Epoch [5/15] | Accuracy: 0.7434
# Subject 11 | Epoch [6/15] | Loss: 0.5633
# Subject 11 | Epoch [6/15] | Accuracy: 0.7257
# Subject 11 | Epoch [7/15] | Loss: 0.5606
# Subject 11 | Epoch [7/15] | Accuracy: 0.7257
# Subject 11 | Epoch [8/15] | Loss: 0.5332
# Subject 11 | Epoch [8/15] | Accuracy: 0.7212
# Subject 11 | Epoch [9/15] | Loss: 0.5413
# Subject 11 | Epoch [9/15] | Accuracy: 0.7168
# Subject 11 | Epoch [10/15] | Loss: 0.5325
# Subject 11 | Epoch [10/15] | Accuracy: 0.7345
# Subject 11 | Epoch [11/15] | Loss: 0.5403
# Subject 11 | Epoch [11/15] | Accuracy: 0.7345
# Subject 11 | Epoch [12/15] | Loss: 0.5312
# Subject 11 | Epoch [12/15] | Accuracy: 0.7389
# Subject 11 | Epoch [13/15] | Loss: 0.5304
# Subject 11 | Epoch [13/15] | Accuracy: 0.7389
# Subject 11 | Epoch [14/15] | Loss: 0.5269
# Subject 11 | Epoch [14/15] | Accuracy: 0.7434
# Subject 11 | Epoch [15/15] | Loss: 0.5268
# Subject 11 | Epoch [15/15] | Accuracy: 0.7345

# %%
for i, losses in enumerate(epoch_losses):
    plt.plot(range(1, len(losses) + 1), losses, label=f'Subject {i+1}')
plt.title('Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
for i, accuracies in enumerate(epoch_accuracies):
    plt.plot(range(1, len(accuracies) + 1), accuracies, label=f'Subject {i+1}')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot Test Loss vs. Test Accuracy
plt.figure()
plt.plot(test_losses, test_accuracies, marker='o')
plt.title('Test Loss vs Test Accuracy')
plt.xlabel('Test Loss')
plt.ylabel('Test Accuracy')
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

def plot_predictions(y_true, y_pred, subject):
    """
    Plots predictions vs. true labels and the confusion matrix.
    
    Parameters:
    - y_true: Array of true labels
    - y_pred: Array of predicted labels
    - subject: Subject ID for labeling the plots
    """
    # Plot 1: True vs. Predicted Labels
    plt.figure(figsize=(12, 5))
    plt.plot(y_true, label='True Labels', marker='o', linestyle='--', color='b')
    plt.plot(y_pred, label='Predicted Labels', marker='x', linestyle='-', color='r')
    plt.title(f'Subject {subject} - True vs. Predicted Labels')
    plt.xlabel('Sample Index')
    plt.ylabel('State (0: Alert, 1: Drowsy)')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Plot 2: Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Alert", "Drowsy"])
    disp.plot(cmap='Blues')
    plt.title(f'Subject {subject} - Confusion Matrix')
    plt.show()

# %%
subject_id = 2  # Choose any subject between 1 to 11
y_true, y_pred = all_predictions[subject_id]
plot_predictions(y_true, y_pred, subject=subject_id)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 subject_id = 2  # Choose any subject between 1 to 11
# ----> 2 y_true, y_pred = all_predictions[subject_id]
#       3 plot_predictions(y_true, y_pred, subject=subject_id)
#
# NameError: name 'all_predictions' is not defined

# %%
# Load the trained model function
def load_trained_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = CNNLSTM().double().to(device)  # Load CNN-LSTM model
    model.load_state_dict(torch.load("cnn_lstm_model.pth", weights_only=True))  # Load weights only
    return model

# %%
import torch
import scipy.io as sio
import numpy as np

# Load the trained model function
def load_trained_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model = CNNLSTM().double().to(device)  # Load CNN-LSTM model
    model.load_state_dict(torch.load("cnn_lstm_model.pth", weights_only=True))  # Load weights only
    model.eval()  # Set the model to evaluation mode
    return model

# Load and prepare test data
def load_test_data():
    filename = '/kaggle/input/eeg-driver-drowsiness-dataset/dataset (2).mat'  # Update this to the correct path of your test data
    data = sio.loadmat(filename)
    x_test = np.array(data['EEGsample'])  # Adjust this based on your test data structure
    return x_test

# Prepare test data for prediction
def prepare_test_data(x_test):
    selectedchan = [28]  # Only channel Oz is used
    x_test = x_test[:, selectedchan, :]  # Select the desired channel
    sf = 128  # Sampling frequency
    x_test = x_test.reshape(x_test.shape[0], 1, 1, 3 * sf)  # Reshape for CNN input
    return x_test

# Main code to run predictions
if __name__ == "__main__":
    # Load the trained model and test data
    model = load_trained_model()
    x_test = load_test_data()

    # Prepare the test data
    x_test_prepared = prepare_test_data(x_test)

    # Convert test data to PyTorch tensor
    x_test_tensor = torch.DoubleTensor(x_test_prepared).cuda()  # Move to GPU if available

    # Make predictions
    with torch.no_grad():
        output = model(x_test_tensor)  # Forward pass
        probabilities = torch.exp(output).cpu().numpy()  # Get probabilities
        predictions = np.argmax(probabilities, axis=1)  # Get predicted classes

    # Output predictions
    for i, pred in enumerate(predictions):
        print(f"Sample {i + 1}: {'Drowsy' if pred == 1 else 'Alert'} (Prediction: {pred})")
